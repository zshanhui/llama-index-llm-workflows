# %% [markdown]
# # Invoice, SKU & Product Catalog Matching Workflow
#
# <a href="https://colab.research.google.com/github/run-llama/llamacloud-demo/blob/main/examples/document_workflows/invoice_sku_product_catalog_matching/invoice_sku_product_catalog_matching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# This notebook demonstrates an automated workflow for matching invoice line items with standardized product catalog SKUs. The system helps standardize product identification across varying textual descriptions.

# %% [markdown]
# ![End to End Process](e2eprocess.png)

# %% [markdown]
# #### The Challenge: Understanding Product Variations
#
# Example: When you have an invoice line item like "10 boxes of Acme Widget Model X", the line item only shows a textual description, but you maintain a separate product catalog with standardized SKU codes and other information.
#
# #### The Documents We Work With
#
# 1. **Invoice Data**: (`invoice.pdf`)
#    * Contains line items with various product descriptions
#    * Each line includes:
#      * Invoice ID (e.g., INV-2024-001)
#      * Line item description
#      * Quantity
#      * Unit price
#      * Date
#    * Contains 25 different line items
#
# 2. **Product Catalog**: (`product_catalog.csv`)
#    * Contains standardized product information:
#      * SKU codes (e.g., ACM-WX-001)
#      * Standard product names
#      * Categories
#      * Manufacturers
#      * Descriptions
#      * Unit prices
#    * Contains 50 different products
#
# #### Enrichment Process
#
# 1. Parse the line item description
# 2. Query the product catalog index using RAG to find the closest matching SKU
# 3. Append the SKU and standardized product information to the line item
#
# #### Value Added
#
# Now your systems can unify reporting across different product descriptions that actually refer to the same standard product. For example:
#
# Different descriptions in invoices:
# ```
# "Acme Widget Model X Premium"
# "ACME Premium Widget X"
# "Widget X by Acme Corp"
# ```
#
# All match to the same standardized product:
# ```
# SKU: ACM-WX-001
# Standard Name: Acme Widget X
# Category: Widgets
# Manufacturer: Acme Corporation
# ```
#
# #### Implementation
#
# The workflow uses:
# * LlamaParse for PDF invoice parsing
# * Structured data handling with LLMs and Pydantic models
# * VectorStoreIndex (Vector similarity) for product matching
#
# #### Input/Output Files
#
# **Inputs:**
# - `invoice.pdf`: Invoice containing line items
# - `product_catalog.csv`: Reference product catalog
#
# **Output:**
# - `enriched_invoice.csv`: Invoice data enriched with matched SKUs and standardized product information

# %% [markdown]
# ### Installation

# %%
# !pip install llama-parse llama-index
# Out:
# Requirement already satisfied: llama-parse in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (0.5.18)
# Requirement already satisfied: llama-index in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (0.12.8)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-parse) (8.1.8)
# Requirement already satisfied: llama-index-core>=0.11.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-parse) (0.12.8)
# Requirement already satisfied: pydantic!=2.10 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-parse) (2.10.3)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index) (0.6.3)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index) (0.3.12)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.58.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core>=0.11.0->llama-parse) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (3.11.11)
# Requirement already satisfied: dataclasses-json in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (2024.12.0)
# Requirement already satisfied: httpx in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (3.4.2)
# Requirement already satisfied: numpy in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (2.2.1)
# Requirement already satisfied: pillow>=9.0.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (11.0.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (0.9.0)
# Requirement already satisfied: wrapt in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (1.17.0)
# Requirement already satisfied: llama-cloud>=0.1.5 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.7)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (4.12.3)
# Requirement already satisfied: pandas in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.2.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: joblib in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from pydantic!=2.10->llama-parse) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from pydantic!=2.10->llama-parse) (2.27.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (1.18.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.6)
# Requirement already satisfied: certifi<2025.0.0,>=2024.7.4 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-cloud>=0.1.5->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2024.12.14)
# Requirement already satisfied: anyio in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from httpx->llama-index-core>=0.11.0->llama-parse) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from httpx->llama-index-core>=0.11.0->llama-parse) (1.0.7)
# Requirement already satisfied: idna in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from httpx->llama-index-core>=0.11.0->llama-parse) (3.4)
# Requirement already satisfied: sniffio in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from httpx->llama-index-core>=0.11.0->llama-parse) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core>=0.11.0->llama-parse) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core>=0.11.0->llama-parse) (3.0.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core>=0.11.0->llama-parse) (1.26.14)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core>=0.11.0->llama-parse) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core>=0.11.0->llama-parse) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from dataclasses-json->llama-index-core>=0.11.0->llama-parse) (3.23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2024.2)
# Requirement already satisfied: packaging>=17.0 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core>=0.11.0->llama-parse) (24.2)
# Requirement already satisfied: six>=1.5 in /Users/lishanhui/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (1.16.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Setup API Keys

# %%
import os

os.environ['LLAMA_CLOUD_API_KEY'] = 'your_llama_cloud_key_here ' # Get your API Key from https://cloud.llamaindex.ai/
os.environ['OPENAI_API_KEY'] = 'openai_api_key' # Get your API Key from https://platform.openai.com/

# %% [markdown]
# ### Imports

# %%
from typing import List, Optional
from pydantic import BaseModel, Field
from decimal import Decimal
from datetime import date
from pathlib import Path
import pandas as pd

# %%
from llama_index.core.workflow import (
    Event,
    StartEvent,
    StopEvent,
    Context,
    Workflow,
    step,
)

# %%
from llama_index.core import VectorStoreIndex, Document
from llama_index.core.llms import LLM
from llama_index.core.retrievers import BaseRetriever
from llama_index.core.prompts import ChatPromptTemplate
from llama_parse import LlamaParse
from llama_index.llms.openai import OpenAI

# %% [markdown]
# ### Data Models
#
# Here, we define the Pydantic models that are essential for processing invoice line items and matching them with standardized product catalog entries. Pydantic models are used because they provide strict type checking and data validation while ensuring consistent data structures throughout the workflow.
#
# #### Pydantic Models For Raw Invoice Data
#
# `InvoiceLineItem`: Represents a single line item from an invoice, capturing:
# - Invoice identifier
# - Product description as it appears on the invoice
# - Quantity ordered
# - Unit price
# - Invoice date
#
# `InvoiceOutput`: Container model that holds all line items extracted from an invoice.
#
# #### Pydantic Models for Product Catalog
#
# `ProductCatalog`: Represents a single product entry in the standardized catalog with:
# - SKU identifier
# - Standard product name
# - Product category
# - Manufacturer information
# - Detailed description
# - Standard unit price
#
# #### Pydantic Models for Enriched Output
#
# `EnrichedLineItem`: Represents a line item after SKU matching, containing:
# - Original invoice information
# - Matched product catalog data
# - Match confidence score
#
# `EnrichedInvoice`: Complete representation of an invoice after SKU matching, containing:
# - List of enriched line items with their matched catalog information

# %%
# Pydantic Models for Invoice Data
class InvoiceLineItem(BaseModel):
    """
    Represents a single line item from an invoice.
    Each line item contains details about the product ordered, quantity, and pricing.
    """
    invoice_id: str = Field(
        description="Unique identifier for the invoice (e.g., 'INV-2024-001')"
    )
    line_item: str = Field(
        description="Description of the product or service as it appears on the invoice"
    )
    quantity: int = Field(
        description="Number of units ordered",
        gt=0  # Ensures quantity is greater than 0
    )
    unit_price: Decimal = Field(
        description="Price per unit in decimal format (e.g., 45.99)",
        gt=0  # Ensures price is greater than 0
    )
    date_: date = Field(
        description="Date of the invoice in YYYY-MM-DD format"
    )

class InvoiceOutput(BaseModel):
    """
    Container model for all line items from an invoice.
    Used as the output format when parsing invoice documents.
    """
    line_items: List[InvoiceLineItem] = Field(
        description="List of all line items extracted from the invoice"
    )

# Pydantic Models for Product Catalog
class ProductCatalog(BaseModel):
    """
    Represents a single product entry in the product catalog.
    Contains standardized product information and SKU details.
    """
    sku: str = Field(
        description="Stock Keeping Unit - unique identifier for the product (e.g., 'ACM-WX-001')"
    )
    standard_name: str = Field(
        description="Standardized product name used across the system"
    )
    category: str = Field(
        description="Product category or classification (e.g., 'Widgets', 'Fasteners')"
    )
    manufacturer: str = Field(
        description="Name of the product manufacturer or supplier"
    )
    description: str = Field(
        description="Detailed product description"
    )
    unit_price: Decimal = Field(
        description="Standard unit price in decimal format",
        gt=0
    )

# Pydantic Models for Enriched Output
class EnrichedLineItem(BaseModel):
    """
    Enhanced version of InvoiceLineItem that includes matched product catalog information.
    Combines original invoice data with standardized product details.
    """
    invoice_id: str = Field(
        description="Original invoice identifier"
    )
    original_line_item: str = Field(
        description="Original product description from the invoice"
    )
    quantity: int = Field(
        description="Quantity ordered",
        gt=0
    )
    unit_price: Decimal = Field(
        description="Original unit price from invoice",
        gt=0
    )
    date_: date = Field(
        description="Invoice date"
    )
    matched_sku: Optional[str] = Field(
        None,
        description="Matched SKU from product catalog, if found"
    )
    standard_name: Optional[str] = Field(
        None,
        description="Standardized product name from catalog"
    )
    category: Optional[str] = Field(
        None,
        description="Product category from catalog"
    )
    manufacturer: Optional[str] = Field(
        None,
        description="Manufacturer information from catalog"
    )
    match_confidence: Optional[float] = Field(
        None,
        description="Confidence score of the SKU match (0.0 to 1.0)",
        ge=0.0,  # Greater than or equal to 0
        le=1.0   # Less than or equal to 1
    )

class EnrichedInvoice(BaseModel):
    """
    Container model for enriched invoice data.
    Contains all line items with their matched product catalog information.
    """
    line_items: List[EnrichedLineItem] = Field(
        description="List of all enriched line items with matched catalog data"
    )

# %% [markdown]
# ### Event Models for Workflow
#
# `InvoiceEvent`: Carries parsed invoice data through the workflow
# `EnrichedEvent`: Carries enriched data after SKU matching
# `LogEvent`: Handles logging and progress updates during processing
#
# These models form a pipeline where:
# 1. Raw invoice data is parsed into `InvoiceLineItem` objects
# 2. Each line item is matched against `ProductCatalog` entries
# 3. Results are combined into `EnrichedLineItem` objects
# 4. Final output is collected in an `EnrichedInvoice`
#
# Example Flow:
#
# ```text
# Raw Invoice Line:
# Line_Item: "Acme Widget Model X Premium, Qty: 10, Price: $45.99"
#        ↓
# InvoiceLineItem:
# {invoice_id: "INV-2024-001", line_item: "Acme Widget Model X Premium", quantity: 10, ...}
#        ↓
# Matched with ProductCatalog:
# {sku: "ACM-WX-001", standard_name: "Acme Widget X", category: "Widgets", ...}
#        ↓
# EnrichedLineItem:
# {line_item: "Acme Widget Model X Premium", matched_sku: "ACM-WX-001", ...}
# ```

# %%
# Event Classes
class InvoiceEvent(Event):
    """
    Workflow event that carries parsed invoice data.
    Triggered after successful invoice parsing step.
    """
    invoice_data: InvoiceOutput = Field(
        description="Parsed invoice data containing all line items"
    )

class EnrichedEvent(Event):
    """
    Workflow event that carries enriched invoice data.
    Triggered after successful SKU matching step.
    """
    enriched_data: EnrichedInvoice = Field(
        description="Enriched invoice data with matched catalog information"
    )

class LogEvent(Event):
    """
    Workflow event for logging messages and progress updates.
    Used throughout the workflow to provide status information.
    """
    msg: str = Field(
        description="Log message content"
    )
    delta: bool = Field(
        False,
        description="Flag indicating if this is a partial update to previous message"
    )

# %% [markdown]
# ### Prompt
#
# Here we define prompt for extraction of information from the invoice.

# %%
# Extract Prompt Template
EXTRACT_PROMPT = '''
Extract the invoice table data from the following content into a structured format.
Each row should include invoice_id, line_item, quantity, unit_price, and date fields.

invoice_data:
{invoice_data}

Extract each row and format according to the provided schema.
Ensure dates are in YYYY-MM-DD format and all numbers are properly formatted.
'''

# %% [markdown]
# ### Creating the Product Catalog Index
#
# Before we can match invoice line items to standard products, we need to create a searchable index of our product catalog. This function creates a vector store index that combines product names, manufacturers, and descriptions into searchable embeddings. Each product's metadata (SKU, category, etc.) is stored alongside its embedding, allowing us to retrieve full product details when we find a match.
#
# Example: When searching for "Acme Widget Model X Premium", the index will help find the closest matching product based on semantic similarity rather than exact text matching.

# %%
def create_product_catalog_index(
    catalog_csv_path: str,
    llm: Optional[LLM] = None
) -> BaseRetriever:
    """Create a vector store index from the product catalog CSV."""
    # Read the CSV
    df = pd.read_csv(catalog_csv_path)
    
    # Create documents for indexing
    documents = []
    for _, row in df.iterrows():
        # Combine fields for embedding
        text = f"{row['standard_name']} {row['manufacturer']} {row['description']}"
        print(f'product catalog index:: {text}')
        
        # Store other fields as metadata
        metadata = {
            "sku": row["sku"],
            "standard_name": row["standard_name"],
            "category": row["category"],
            "manufacturer": row["manufacturer"],
            "unit_price": row["unit_price"]
        }
        
        doc = Document(text=text, metadata=metadata)
        documents.append(doc)
    
    # Create and return the index
    index = VectorStoreIndex.from_documents(
        documents
    )
    
    return index.as_retriever(similarity_top_k=1)

# %% [markdown]
# ### Main Workflow Implementation
#
# Here we implement the workflow for SKU matching and product standardization.

# %% [markdown]
# ![Worflow](workflow.png)

# %% [markdown]
# **a) Parse Invoice (First Step)**
# - Triggered by: Initial StartEvent
# - Reads invoice PDF using LlamaParse
# - Uses LLM to extract structured line item data
# - Outputs: InvoiceEvent containing structured line items
#
# **b) Match Line Items with SKUs**
# - Triggered by: InvoiceEvent
# - For each line item:
#   - Queries product catalog index using vector similarity
#   - Finds best matching SKU
#   - Records match confidence
# - Outputs: EnrichedEvent with matched product information
#
# **c) Generate Final Output**
# - Triggered by: EnrichedEvent
# - Combines all enriched line items
# - Creates standardized CSV output
# - Includes original and matched data
# - Outputs: StopEvent with final results
#
# The event flow looks like this:
# ```
# StartEvent
#   → InvoiceEvent
#     → EnrichedEvent
#       → StopEvent
# ```
#
# Throughout the workflow:
# 1. LogEvents provide progress updates
# 2. Context (ctx) stores the product catalog index
# 3. Events carry structured data between steps
# 4. Each step runs asynchronously (@step decorator)
# 5. Match confidence scores help validate results
#
# The workflow uses vector similarity searching to match product descriptions to standard SKUs, maintaining accuracy while handling variations in product naming.

# %%
class SKUMatchingWorkflow(Workflow):
    """End-to-end workflow for invoice processing and SKU matching."""

    def __init__(
        self,
        parser: LlamaParse,
        catalog_retriever: BaseRetriever,
        llm: LLM,
        output_dir: str = "data_out",
        **kwargs,
    ) -> None:
        super().__init__(**kwargs)
        
        self.parser = parser
        self.retriever = catalog_retriever
        self.llm = llm
        
        # Setup output directory
        out_path = Path(output_dir) / 'workflow_output'
        if not out_path.exists():
            out_path.mkdir(parents=True, exist_ok=True)
        self.output_dir = out_path

    @step
    async def parse_invoice(
        self, ctx: Context, ev: StartEvent
    ) -> InvoiceEvent:
        """Parse the invoice PDF and extract structured data."""
        if self._verbose:
            ctx.write_event_to_stream(LogEvent(msg=">> Parsing invoice PDF"))
            
        # Parse PDF using LlamaParse
        docs = await self.parser.aload_data(ev.invoice_path)
        invoice_data = "\n".join([d.get_content(metadata_mode="all") for d in docs])
        print(f'invoice_data >> {invoice}')

        # Create extraction prompt
        prompt = ChatPromptTemplate.from_messages([
            ("system", "You are an assistant that extracts structured data from invoice tables."),
            ("user", EXTRACT_PROMPT)
        ])
        
        # Extract structured data
        invoice_structured_data = await self.llm.astructured_predict(
            InvoiceOutput,
            prompt,
            invoice_data=invoice_data
        )

        print('invoice_structured_data >> ', invoice_structured_data)
        
        if self._verbose:
            ctx.write_event_to_stream(
                LogEvent(msg=f">> Extracted {len(invoice_structured_data.line_items)} line items")
            )
            
        return InvoiceEvent(invoice_data=invoice_structured_data)

    @step
    async def match_skus(
        self, ctx: Context,
        ev: InvoiceEvent
    ) -> EnrichedEvent:
        """Match each line item with product catalog SKUs."""
        if self._verbose:
            ctx.write_event_to_stream(LogEvent(msg=">> Matching SKUs"))
            
        enriched_items = []

        for item in ev.invoice_data.line_items:
            # Query the catalog index
            matches = self.retriever.retrieve(item.line_item)
            print('all matches >> ', matches)
            
            if matches and len(matches) > 0:
                top_match = matches[0]
                metadata = top_match.metadata
                enriched_item = EnrichedLineItem(
                    invoice_id=item.invoice_id,
                    original_line_item=item.line_item,
                    quantity=item.quantity,
                    unit_price=item.unit_price,
                    date_=item.date_,
                    matched_sku=metadata.get("sku"),
                    standard_name=metadata.get("standard_name"),
                    category=metadata.get("category"),
                    manufacturer=metadata.get("manufacturer"),
                    match_confidence=top_match.score if hasattr(top_match, "score") else None
                )
            else:
                enriched_item = EnrichedLineItem(
                    invoice_id=item.invoice_id,
                    original_line_item=item.line_item,
                    quantity=item.quantity,
                    unit_price=item.unit_price,
                    date_=item.date_
                )
            
            enriched_items.append(enriched_item)

        return EnrichedEvent(
            enriched_data=EnrichedInvoice(line_items=enriched_items)
        )

    @step
    async def save_output(
        self, ctx: Context, ev: EnrichedEvent
    ) -> StopEvent:
        """Save the enriched data to CSV."""
        if self._verbose:
            ctx.write_event_to_stream(LogEvent(msg=">> Saving enriched data"))
            
        # Convert to DataFrame
        output_data = []
        for item in ev.enriched_data.line_items:
            output_data.append({
                "invoice_id": item.invoice_id,
                "line_item": item.original_line_item,
                "quantity": item.quantity,
                "unit_price": float(item.unit_price),
                "date": item.date_,
                "matched_sku": item.matched_sku,
                "standard_name": item.standard_name,
                "category": item.category,
                "manufacturer": item.manufacturer,
                "match_confidence": item.match_confidence
            })

        df = pd.DataFrame(output_data)
        
        # Save to CSV
        output_path = self.output_dir / "enriched_invoice.csv"
        df.to_csv(output_path, index=False)
        
        if self._verbose:
            ctx.write_event_to_stream(
                LogEvent(msg=f">> Saved output to {output_path}")
            )
        
        return StopEvent(result=ev.enriched_data)

# %% [markdown]
# ### Create workflow
#
# Here we initialize LLM, parser, create product catalog index and create the workflow.
#
# Note: The default timeout for running the workflow is 10 seconds. However, since parsing and various LLM calls often take longer than 10 seconds, we have opted to extend the timeout to 300 seconds.

# %%
parser = LlamaParse(result_type="markdown")
llm = OpenAI(model="gpt-4o")

# Create product catalog index
catalog_retriever = create_product_catalog_index(
    "product-catalog.csv",
    llm=llm
)

# Initialize workflow
workflow = SKUMatchingWorkflow(
    parser=parser,
    catalog_retriever=catalog_retriever,
    llm=llm,
    verbose=True,
    timeout=300
)
# Out:
# product catalog index:: Acme Widget X Standard Acme Corporation Standard quality industrial widget Model X series
# product catalog index:: Acme Widget X Premium Acme Corporation Premium quality industrial widget Model X series with enhanced features
# product catalog index:: Widget X Maintenance Kit Acme Corporation Replacement and maintenance kit for Widget X series
# product catalog index:: Widget X Enterprise Bundle Acme Corporation Complete enterprise solution including Widget X and accessories
# product catalog index:: Widget X Service Bundle Acme Corporation Comprehensive service package for Widget X products
# product catalog index:: Industrial Fastener 2-inch Industrial Supply Co 2-inch blue-coated industrial grade fasteners
# product catalog index:: Premium Steel Fasteners 2-inch Industrial Supply Co 2-inch premium steel fasteners with corrosion resistance
# product catalog index:: Industrial Fastener Kit Mixed Industrial Supply Co Comprehensive kit of industrial fasteners in various sizes
# product catalog index:: Ergonomic Office Chair Pro ErgoComfort Professional-grade ergonomic office chair with lumbar support
# product catalog index:: Standing Desk Converter XL ErgoComfort Extra-large standing desk converter with dual monitor support
# product catalog index:: Ergonomic Mouse Pad Pro ErgoComfort Professional ergonomic mouse pad with wrist support
# product catalog index:: Premium Desk Mat Extended ErgoComfort Extended size premium desk mat with anti-slip base
# product catalog index:: Premium Office Chair Mat ErgoComfort Heavy-duty chair mat for carpet protection
# product catalog index:: LED Monitor Stand Deluxe TechPro Adjustable monitor stand with LED lighting
# product catalog index:: Dual Monitor Arm Professional TechPro Professional-grade dual monitor arm with cable management
# product catalog index:: Anti-Glare Screen Protector XL TechPro Large anti-glare screen protector for monitors up to 32"
# product catalog index:: Wireless Keyboard MK-7000 TechPro Professional wireless keyboard with programmable keys
# product catalog index:: Cable Management Kit Pro OfficePro Professional cable management solution kit
# product catalog index:: Professional Cable Ties OfficePro Heavy-duty professional cable ties pack of 100
# product catalog index:: Desktop Power Hub Pro TechPro Professional desktop power hub with surge protection
# product catalog index:: Widget X Plus Edition Acme Corporation Enhanced Widget X with additional features
# product catalog index:: Widget X Professional Kit Acme Corporation Professional-grade Widget X toolkit
# product catalog index:: Adjustable Desk Platform ErgoComfort Height-adjustable desk platform with memory settings
# product catalog index:: Premium Standing Desk ErgoComfort Electric standing desk with programmable height presets
# product catalog index:: Ergonomic Keyboard Tray ErgoComfort Adjustable under-desk keyboard tray
# product catalog index:: Monitor Riser with Storage ErgoComfort Monitor riser with built-in storage compartments
# product catalog index:: Monitor Privacy Screen TechPro Privacy screen filter for monitors
# product catalog index:: Monitor Cleaning Kit Pro TechPro Professional monitor cleaning kit with solutions
# product catalog index:: Mechanical Keyboard Pro TechPro Professional mechanical keyboard with RGB lighting
# product catalog index:: Ergonomic Split Keyboard TechPro Split design ergonomic keyboard
# product catalog index:: Under-Desk Cable Tray OfficePro Professional under-desk cable management tray
# product catalog index:: Vertical Cable Manager OfficePro Vertical cable management solution
# product catalog index:: Surge Protector Premium TechPro Premium surge protector with USB ports
# product catalog index:: Wireless Charging Pad Pro TechPro Professional Qi wireless charging pad
# product catalog index:: Security Fasteners Kit Industrial Supply Co Security-grade fastener kit with special tools
# product catalog index:: Decorative Fasteners Set Industrial Supply Co Premium decorative fastener set
# product catalog index:: Widget X Developer Edition Acme Corporation Specialized Widget X for development environments
# product catalog index:: Widget X Analytics Package Acme Corporation Analytics suite for Widget X platform
# product catalog index:: Gaming Chair Professional ErgoComfort Professional gaming chair with ergonomic features
# product catalog index:: Conference Room Chair Pro ErgoComfort Professional conference room chair set
# product catalog index:: Footrest Pro ErgoComfort Adjustable ergonomic footrest
# product catalog index:: Lumbar Support Cushion ErgoComfort Premium lumbar support cushion
# product catalog index:: Monitor Light Bar TechPro LED monitor light bar with brightness control
# product catalog index:: Monitor Desk Mount Basic TechPro Basic monitor desk mount
# product catalog index:: Compact Keyboard Pro TechPro Professional compact keyboard design
# product catalog index:: Keyboard Palm Rest Premium TechPro Premium keyboard palm rest
# product catalog index:: Cable Sleeve Kit OfficePro Professional cable sleeve management kit
# product catalog index:: Cable Clips Pro Pack OfficePro Professional cable clips variety pack
# product catalog index:: International Power Adapter TechPro Universal international power adapter
# product catalog index:: USB-C Power Hub TechPro USB-C power hub with multiple ports
# product catalog index:: Magnetic Fastener Set Industrial Supply Co Magnetic fastener set for special applications
# product catalog index:: Quick-Release Fasteners Industrial Supply Co Professional quick-release fastener kit

# %% [markdown]
# ### Visualize workflow

# %%
from llama_index.utils.workflow import draw_all_possible_flows

draw_all_possible_flows(SKUMatchingWorkflow, filename="sku_matching_workflow.html")
# Out:
# <class 'NoneType'>
# <class '__main__.EnrichedEvent'>
# <class '__main__.InvoiceEvent'>
# <class 'llama_index.core.workflow.events.StopEvent'>
# sku_matching_workflow.html

# %% [markdown]
# ![Visualize Workflow](workflow_visualization.png)

# %% [markdown]
# ### Run the workflow
# Here we run the workflow and check the final result

# %%
# Run workflow
handler = workflow.run(invoice_path="invoice.pdf")
async for event in handler.stream_events():
    if isinstance(event, LogEvent):
        print(event.msg)
        
result = await handler
# Out:
# Running step parse_invoice
# >> Parsing invoice PDF
# Started parsing the file under job_id a5dcb0a7-07bf-435c-ae91-c2f4bdb94a09
# invoice_data >> # Invoice
#
# |invoice_id|line_item|quantity|unit_price|date|
# |---|---|---|---|---|
# |INV-2024-001|Acme Widget Model X Premium|10|45.99|2024-01-15|
# |INV-2024-001|Blue Industrial Fasteners 2-inch|25|0.99|2024-01-15|
# |INV-2024-001|Widget X Replacement Parts Kit|2|15.50|2024-01-15|
# |INV-2024-002|ACME Premium Widget X|15|45.99|2024-01-16|
# |INV-2024-002|Industrial Blue Bolt Pack (2")|30|0.99|2024-01-16|
# |INV-2024-003|Replacement Kit - Widget Model X|5|15.50|2024-01-17|
# |INV-2024-003|Widget X by Acme Corp|8|45.99|2024-01-17|
# |INV-2024-004|Heavy Duty Office Chair - Ergonomic Pro|5|299.99|2024-01-20|
# |INV-2024-004|Wireless Keyboard MK-7000|12|89.99|2024-01-20|
# |INV-2024-005|LED Monitor Stand Deluxe|8|79.99|2024-01-22|
# |INV-2024-005|Anti-Glare Screen Protector XL|15|24.99|2024-01-22|
# |INV-2024-006|Premium Desk Mat - Extended|20|34.99|2024-01-25|
# |INV-2024-006|Cable Management Kit Pro|30|19.99|2024-01-25|
# |INV-2024-007|Acme Widget X Plus Edition|12|55.99|2024-01-28|
# |INV-2024-007|Steel Fasteners Pack - 2" Premium|40|1.29|2024-01-28|
# |INV-2024-008|Widget X Service Bundle|3|149.99|2024-01-30|
# |INV-2024-008|Ergonomic Mouse Pad Pro|25|15.99|2024-01-30|
# |INV-2024-009|Standing Desk Converter XL|6|249.99|2024-02-01|
# |INV-2024-009|Dual Monitor Arm - Professional|10|129.99|2024-02-01|
# |INV-2024-010|Widget X Enterprise Bundle|2|399.99|2024-02-03|
# |INV-2024-010|Industrial Fastener Kit - Mixed Sizes|15|45.99|2024-02-03|
# |INV-2024-011|Professional Cable Ties (Pack of 100)|10|9.99|2024-02-05|
# |INV-2024-011|Widget X Maintenance Bundle|4|89.99|2024-02-05|
# |INV-2024-012|Premium Office Chair Mat|8|59.99|2024-02-08|
# |INV-2024-012|Desktop Power Hub Pro|15|49.99|2024-02-08|
# invoice_structured_data >>  line_items=[InvoiceLineItem(invoice_id='INV-2024-001', line_item='Acme Widget Model X Premium', quantity=10, unit_price=Decimal('45.99'), date_=datetime.date(2024, 1, 15)), InvoiceLineItem(invoice_id='INV-2024-001', line_item='Blue Industrial Fasteners 2-inch', quantity=25, unit_price=Decimal('0.99'), date_=datetime.date(2024, 1, 15)), InvoiceLineItem(invoice_id='INV-2024-001', line_item='Widget X Replacement Parts Kit', quantity=2, unit_price=Decimal('15.5'), date_=datetime.date(2024, 1, 15)), InvoiceLineItem(invoice_id='INV-2024-002', line_item='ACME Premium Widget X', quantity=15, unit_price=Decimal('45.99'), date_=datetime.date(2024, 1, 16)), InvoiceLineItem(invoice_id='INV-2024-002', line_item='Industrial Blue Bolt Pack (2")', quantity=30, unit_price=Decimal('0.99'), date_=datetime.date(2024, 1, 16)), InvoiceLineItem(invoice_id='INV-2024-003', line_item='Replacement Kit - Widget Model X', quantity=5, unit_price=Decimal('15.5'), date_=datetime.date(2024, 1, 17)), InvoiceLineItem(invoice_id='INV-2024-003', line_item='Widget X by Acme Corp', quantity=8, unit_price=Decimal('45.99'), date_=datetime.date(2024, 1, 17)), InvoiceLineItem(invoice_id='INV-2024-004', line_item='Heavy Duty Office Chair - Ergonomic Pro', quantity=5, unit_price=Decimal('299.99'), date_=datetime.date(2024, 1, 20)), InvoiceLineItem(invoice_id='INV-2024-004', line_item='Wireless Keyboard MK-7000', quantity=12, unit_price=Decimal('89.99'), date_=datetime.date(2024, 1, 20)), InvoiceLineItem(invoice_id='INV-2024-005', line_item='LED Monitor Stand Deluxe', quantity=8, unit_price=Decimal('79.99'), date_=datetime.date(2024, 1, 22)), InvoiceLineItem(invoice_id='INV-2024-005', line_item='Anti-Glare Screen Protector XL', quantity=15, unit_price=Decimal('24.99'), date_=datetime.date(2024, 1, 22)), InvoiceLineItem(invoice_id='INV-2024-006', line_item='Premium Desk Mat - Extended', quantity=20, unit_price=Decimal('34.99'), date_=datetime.date(2024, 1, 25)), InvoiceLineItem(invoice_id='INV-2024-006', line_item='Cable Management Kit Pro', quantity=30, unit_price=Decimal('19.99'), date_=datetime.date(2024, 1, 25)), InvoiceLineItem(invoice_id='INV-2024-007', line_item='Acme Widget X Plus Edition', quantity=12, unit_price=Decimal('55.99'), date_=datetime.date(2024, 1, 28)), InvoiceLineItem(invoice_id='INV-2024-007', line_item='Steel Fasteners Pack - 2" Premium', quantity=40, unit_price=Decimal('1.29'), date_=datetime.date(2024, 1, 28)), InvoiceLineItem(invoice_id='INV-2024-008', line_item='Widget X Service Bundle', quantity=3, unit_price=Decimal('149.99'), date_=datetime.date(2024, 1, 30)), InvoiceLineItem(invoice_id='INV-2024-008', line_item='Ergonomic Mouse Pad Pro', quantity=25, unit_price=Decimal('15.99'), date_=datetime.date(2024, 1, 30)), InvoiceLineItem(invoice_id='INV-2024-009', line_item='Standing Desk Converter XL', quantity=6, unit_price=Decimal('249.99'), date_=datetime.date(2024, 2, 1)), InvoiceLineItem(invoice_id='INV-2024-009', line_item='Dual Monitor Arm - Professional', quantity=10, unit_price=Decimal('129.99'), date_=datetime.date(2024, 2, 1)), InvoiceLineItem(invoice_id='INV-2024-010', line_item='Widget X Enterprise Bundle', quantity=2, unit_price=Decimal('399.99'), date_=datetime.date(2024, 2, 3)), InvoiceLineItem(invoice_id='INV-2024-010', line_item='Industrial Fastener Kit - Mixed Sizes', quantity=15, unit_price=Decimal('45.99'), date_=datetime.date(2024, 2, 3)), InvoiceLineItem(invoice_id='INV-2024-011', line_item='Professional Cable Ties (Pack of 100)', quantity=10, unit_price=Decimal('9.99'), date_=datetime.date(2024, 2, 5)), InvoiceLineItem(invoice_id='INV-2024-011', line_item='Widget X Maintenance Bundle', quantity=4, unit_price=Decimal('89.99'), date_=datetime.date(2024, 2, 5)), InvoiceLineItem(invoice_id='INV-2024-012', line_item='Premium Office Chair Mat', quantity=8, unit_price=Decimal('59.99'), date_=datetime.date(2024, 2, 8)), InvoiceLineItem(invoice_id='INV-2024-012', line_item='Desktop Power Hub Pro', quantity= ...
# Step parse_invoice produced event InvoiceEvent
# >> Extracted 25 line items
# Running step match_skus
# all matches >>  [NodeWithScore(node=TextNode(id_='41cf6349-aa7b-456a-baa1-0fd370c2ccaf', embedding=None, metadata={'sku': 'ACM-WX-002', 'standard_name': 'Acme Widget X Premium', 'category': 'Widgets', 'manufacturer': 'Acme Corporation', 'unit_price': 55.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='fbc0e31d-0143-4392-8ad1-205a00790adc', node_type='4', metadata={'sku': 'ACM-WX-002', 'standard_name': 'Acme Widget X Premium', 'category': 'Widgets', 'manufacturer': 'Acme Corporation', 'unit_price': 55.99}, hash='0fb93a005aa74fa0c0ef86a82d015331e8c6f94214be37f7cd9a46e12de3f998')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Acme Widget X Premium Acme Corporation Premium quality industrial widget Model X series with enhanced features', mimetype='text/plain', start_char_idx=0, end_char_idx=110, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9185834703840895)]
# all matches >>  [NodeWithScore(node=TextNode(id_='8ac7739d-0324-4c8d-8d9a-7b6cb41eaac7', embedding=None, metadata={'sku': 'IND-FST-201', 'standard_name': 'Industrial Fastener 2-inch', 'category': 'Fasteners', 'manufacturer': 'Industrial Supply Co', 'unit_price': 0.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5f5725fa-45d4-4410-b7f3-f1724b1bbf3a', node_type='4', metadata={'sku': 'IND-FST-201', 'standard_name': 'Industrial Fastener 2-inch', 'category': 'Fasteners', 'manufacturer': 'Industrial Supply Co', 'unit_price': 0.99}, hash='194e2493288e7638d7cfd422cd8a372f2d6abc08020400d69a854bc0c7da343b')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Industrial Fastener 2-inch Industrial Supply Co 2-inch blue-coated industrial grade fasteners', mimetype='text/plain', start_char_idx=0, end_char_idx=93, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9103064091131065)]
# all matches >>  [NodeWithScore(node=TextNode(id_='bb5793c8-0d99-4119-b04c-4c3e9a209412', embedding=None, metadata={'sku': 'ACM-WX-003', 'standard_name': 'Widget X Maintenance Kit', 'category': 'Spare Parts', 'manufacturer': 'Acme Corporation', 'unit_price': 15.5}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='c9af3d64-9e98-4f8d-b62c-90847941c1d1', node_type='4', metadata={'sku': 'ACM-WX-003', 'standard_name': 'Widget X Maintenance Kit', 'category': 'Spare Parts', 'manufacturer': 'Acme Corporation', 'unit_price': 15.5}, hash='e456557af6189e75748b6e6fbcbcadc6c033e6e77c5d6905db16ae59022540db')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Widget X Maintenance Kit Acme Corporation Replacement and maintenance kit for Widget X series', mimetype='text/plain', start_char_idx=0, end_char_idx=93, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.8792678438436963)]
# all matches >>  [NodeWithScore(node=TextNode(id_='41cf6349-aa7b-456a-baa1-0fd370c2ccaf', embedding=None, metadata={'sku': 'ACM-WX-002', 'standard_name': 'Acme Widget X Premium', 'category': 'Widgets', 'manufacturer': 'Acme Corporation', 'unit_price': 55.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='fbc0e31d-0143-4392-8ad1-205a00790adc', node_type='4', metadata={'sku': 'ACM-WX-002', 'standard_name': 'Acme Widget X Premium', 'category': 'Widgets', 'manufacturer': 'Acme Corporation', 'unit_price': 55.99}, hash='0fb93a005aa74fa0c0ef86a82d015331e8c6f94214be37f7cd9a46e12de3f998')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Acme Widget X Premium Acme Corporation Premium quality industrial widget Model X series with enhanced features', mimetype='text/plain', start_char_idx=0, end_char_idx=110, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9140131851860482)]
# all matches >>  [NodeWithScore(node=TextNode(id_='8ac7739d-0324-4c8d-8d9a-7b6cb41eaac7', embedding=None, metadata={'sku': 'IND-FST-201', 'standard_name': 'Industrial Fastener 2-inch', 'category': 'Fasteners', 'manufacturer': 'Industrial Supply Co', 'unit_price': 0.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5f5725fa-45d4-4410-b7f3-f1724b1bbf3a', node_type='4', metadata={'sku': 'IND-FST-201', 'standard_name': 'Industrial Fastener 2-inch', 'category': 'Fasteners', 'manufacturer': 'Industrial Supply Co', 'unit_price': 0.99}, hash='194e2493288e7638d7cfd422cd8a372f2d6abc08020400d69a854bc0c7da343b')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Industrial Fastener 2-inch Industrial Supply Co 2-inch blue-coated industrial grade fasteners', mimetype='text/plain', start_char_idx=0, end_char_idx=93, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.8382583908338108)]
# all matches >>  [NodeWithScore(node=TextNode(id_='bb5793c8-0d99-4119-b04c-4c3e9a209412', embedding=None, metadata={'sku': 'ACM-WX-003', 'standard_name': 'Widget X Maintenance Kit', 'category': 'Spare Parts', 'manufacturer': 'Acme Corporation', 'unit_price': 15.5}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='c9af3d64-9e98-4f8d-b62c-90847941c1d1', node_type='4', metadata={'sku': 'ACM-WX-003', 'standard_name': 'Widget X Maintenance Kit', 'category': 'Spare Parts', 'manufacturer': 'Acme Corporation', 'unit_price': 15.5}, hash='e456557af6189e75748b6e6fbcbcadc6c033e6e77c5d6905db16ae59022540db')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Widget X Maintenance Kit Acme Corporation Replacement and maintenance kit for Widget X series', mimetype='text/plain', start_char_idx=0, end_char_idx=93, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.8770430277867945)]
# all matches >>  [NodeWithScore(node=TextNode(id_='b55428d9-d9f9-465a-a6bb-fe143190e8c1', embedding=None, metadata={'sku': 'ACM-WX-001', 'standard_name': 'Acme Widget X Standard', 'category': 'Widgets', 'manufacturer': 'Acme Corporation', 'unit_price': 45.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='f244732c-cc01-4c2d-bca9-3aa7b3ca22f3', node_type='4', metadata={'sku': 'ACM-WX-001', 'standard_name': 'Acme Widget X Standard', 'category': 'Widgets', 'manufacturer': 'Acme Corporation', 'unit_price': 45.99}, hash='4e38321c2fb867a925d76512089dd89cc78c3950c862870deee7f2678a8e943b')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Acme Widget X Standard Acme Corporation Standard quality industrial widget Model X series', mimetype='text/plain', start_char_idx=0, end_char_idx=89, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.894901122093113)]
# all matches >>  [NodeWithScore(node=TextNode(id_='bb4fec8e-217a-425a-a471-9f8647da35bc', embedding=None, metadata={'sku': 'ERG-CHR-001', 'standard_name': 'Ergonomic Office Chair Pro', 'category': 'Furniture', 'manufacturer': 'ErgoComfort', 'unit_price': 299.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e69cfb02-8ecf-4d52-b43c-f48a9ec78d12', node_type='4', metadata={'sku': 'ERG-CHR-001', 'standard_name': 'Ergonomic Office Chair Pro', 'category': 'Furniture', 'manufacturer': 'ErgoComfort', 'unit_price': 299.99}, hash='2c221d99dfe160d71a1cbfff5291de195e5bb9bb2432ea9513388d48eedb7fc8')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Ergonomic Office Chair Pro ErgoComfort Professional-grade ergonomic office chair with lumbar support', mimetype='text/plain', start_char_idx=0, end_char_idx=100, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9148976612972604)]
# all matches >>  [NodeWithScore(node=TextNode(id_='249ba607-42a2-46ca-b387-309786bfe1f4', embedding=None, metadata={'sku': 'KB-TEC-001', 'standard_name': 'Wireless Keyboard MK-7000', 'category': 'Input Devices', 'manufacturer': 'TechPro', 'unit_price': 89.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e355508f-a66f-4301-bd20-cb16dff79f45', node_type='4', metadata={'sku': 'KB-TEC-001', 'standard_name': 'Wireless Keyboard MK-7000', 'category': 'Input Devices', 'manufacturer': 'TechPro', 'unit_price': 89.99}, hash='d5de1c0b7fabfe0d6a9d13e8574a43c98e357d8791bea3994b162f9cc83d66d7')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Wireless Keyboard MK-7000 TechPro Professional wireless keyboard with programmable keys', mimetype='text/plain', start_char_idx=0, end_char_idx=87, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9240946937106056)]
# all matches >>  [NodeWithScore(node=TextNode(id_='3e18abe0-5d3d-481b-a8e3-1a158409ee3e', embedding=None, metadata={'sku': 'MON-ACC-001', 'standard_name': 'LED Monitor Stand Deluxe', 'category': 'Monitor Accessories', 'manufacturer': 'TechPro', 'unit_price': 79.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='f3fe2098-5cba-461c-a91c-83c5abf1fc4d', node_type='4', metadata={'sku': 'MON-ACC-001', 'standard_name': 'LED Monitor Stand Deluxe', 'category': 'Monitor Accessories', 'manufacturer': 'TechPro', 'unit_price': 79.99}, hash='9df73a95c5ce67a853ef7f59a125d617e4293870bbcc147b56b4b50cd7a38c0f')}, metadata_template='{key}: {value}', metadata_separator='\n', text='LED Monitor Stand Deluxe TechPro Adjustable monitor stand with LED lighting', mimetype='text/plain', start_char_idx=0, end_char_idx=75, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.909514735141845)]
# all matches >>  [NodeWithScore(node=TextNode(id_='16e31d6b-a6b0-4586-9327-3bb9edd52bec', embedding=None, metadata={'sku': 'MON-ACC-003', 'standard_name': 'Anti-Glare Screen Protector XL', 'category': 'Monitor Accessories', 'manufacturer': 'TechPro', 'unit_price': 24.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e4c93909-cde5-4c92-816c-3d07ad4f186f', node_type='4', metadata={'sku': 'MON-ACC-003', 'standard_name': 'Anti-Glare Screen Protector XL', 'category': 'Monitor Accessories', 'manufacturer': 'TechPro', 'unit_price': 24.99}, hash='6b20554a3c4c0c567e07fcc4195f8d2eaa3c42ae09b67bfa50f0376ec600a47a')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Anti-Glare Screen Protector XL TechPro Large anti-glare screen protector for monitors up to 32"', mimetype='text/plain', start_char_idx=0, end_char_idx=95, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9194043131236014)]
# all matches >>  [NodeWithScore(node=TextNode(id_='76408771-5b75-4f9f-8615-8d57ce99f5c8', embedding=None, metadata={'sku': 'ERG-ACC-002', 'standard_name': 'Premium Desk Mat Extended', 'category': 'Accessories', 'manufacturer': 'ErgoComfort', 'unit_price': 34.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='f3905c64-e1b7-4770-b6f0-efa1430e995e', node_type='4', metadata={'sku': 'ERG-ACC-002', 'standard_name': 'Premium Desk Mat Extended', 'category': 'Accessories', 'manufacturer': 'ErgoComfort', 'unit_price': 34.99}, hash='d32dbd2bec020ed17a07927254e9545243f49e902f9010ba738e3bd5375ab792')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Premium Desk Mat Extended ErgoComfort Extended size premium desk mat with anti-slip base', mimetype='text/plain', start_char_idx=0, end_char_idx=88, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.898253217117237)]
# all matches >>  [NodeWithScore(node=TextNode(id_='5b40cabf-a82d-4911-b926-df4dd3e42f60', embedding=None, metadata={'sku': 'CAB-MGT-001', 'standard_name': 'Cable Management Kit Pro', 'category': 'Cable Management', 'manufacturer': 'OfficePro', 'unit_price': 19.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='f194aec9-dd3c-407b-bdf4-ca7064802194', node_type='4', metadata={'sku': 'CAB-MGT-001', 'standard_name': 'Cable Management Kit Pro', 'category': 'Cable Management', 'manufacturer': 'OfficePro', 'unit_price': 19.99}, hash='0799481d48b1fdf919a8b5549ad84cf121add2a4be4421c083fe2fe79d4c60d0')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Cable Management Kit Pro OfficePro Professional cable management solution kit', mimetype='text/plain', start_char_idx=0, end_char_idx=77, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9250739218584803)]
# all matches >>  [NodeWithScore(node=TextNode(id_='89dd8549-edea-436d-8282-48a14d8f80a3', embedding=None, metadata={'sku': 'ACM-WX-006', 'standard_name': 'Widget X Plus Edition', 'category': 'Widgets', 'manufacturer': 'Acme Corporation', 'unit_price': 55.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='16878a8f-adb8-4c4b-9b81-5b8ec601a559', node_type='4', metadata={'sku': 'ACM-WX-006', 'standard_name': 'Widget X Plus Edition', 'category': 'Widgets', 'manufacturer': 'Acme Corporation', 'unit_price': 55.99}, hash='2a841edaa5d792de0d192a567c606e5311c11b47a91eeaec82eebed4745eb37d')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Widget X Plus Edition Acme Corporation Enhanced Widget X with additional features', mimetype='text/plain', start_char_idx=0, end_char_idx=81, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.931777892446474)]
# all matches >>  [NodeWithScore(node=TextNode(id_='abdda6a3-a84d-4805-835f-960d5099c3b1', embedding=None, metadata={'sku': 'IND-FST-202', 'standard_name': 'Premium Steel Fasteners 2-inch', 'category': 'Fasteners', 'manufacturer': 'Industrial Supply Co', 'unit_price': 1.29}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5fd52e7a-ef7d-47d2-8e4e-51082374d592', node_type='4', metadata={'sku': 'IND-FST-202', 'standard_name': 'Premium Steel Fasteners 2-inch', 'category': 'Fasteners', 'manufacturer': 'Industrial Supply Co', 'unit_price': 1.29}, hash='07259ac604e1cce256be5fd16f2ec3b016438a350b80e735924550d406480941')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Premium Steel Fasteners 2-inch Industrial Supply Co 2-inch premium steel fasteners with corrosion resistance', mimetype='text/plain', start_char_idx=0, end_char_idx=108, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9128260533272925)]
# all matches >>  [NodeWithScore(node=TextNode(id_='3a27ed98-7db0-47c9-864c-c97e8e6c8630', embedding=None, metadata={'sku': 'ACM-WX-005', 'standard_name': 'Widget X Service Bundle', 'category': 'Services', 'manufacturer': 'Acme Corporation', 'unit_price': 149.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='0eabfda1-416c-43cc-a6be-07040b699824', node_type='4', metadata={'sku': 'ACM-WX-005', 'standard_name': 'Widget X Service Bundle', 'category': 'Services', 'manufacturer': 'Acme Corporation', 'unit_price': 149.99}, hash='32a25738ff9be0ebfd52fe1881e55e79ad1710da31d7c111b5f7fb633a85c44e')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Widget X Service Bundle Acme Corporation Comprehensive service package for Widget X products', mimetype='text/plain', start_char_idx=0, end_char_idx=92, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.8792123419191504)]
# all matches >>  [NodeWithScore(node=TextNode(id_='40f1af4c-dcf9-4fc3-a95e-0b279448a35a', embedding=None, metadata={'sku': 'ERG-ACC-001', 'standard_name': 'Ergonomic Mouse Pad Pro', 'category': 'Accessories', 'manufacturer': 'ErgoComfort', 'unit_price': 15.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='c39ce1fb-c829-4f27-9823-78373adf32b7', node_type='4', metadata={'sku': 'ERG-ACC-001', 'standard_name': 'Ergonomic Mouse Pad Pro', 'category': 'Accessories', 'manufacturer': 'ErgoComfort', 'unit_price': 15.99}, hash='bb44f540fb1843bae3c5d2f265a01bb33e17f8d3ebf73330156f90ce965f4418')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Ergonomic Mouse Pad Pro ErgoComfort Professional ergonomic mouse pad with wrist support', mimetype='text/plain', start_char_idx=0, end_char_idx=87, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.940275185020899)]
# all matches >>  [NodeWithScore(node=TextNode(id_='7e489822-0dc6-4e57-8fe3-c3d52c999b95', embedding=None, metadata={'sku': 'ERG-CHR-002', 'standard_name': 'Standing Desk Converter XL', 'category': 'Furniture', 'manufacturer': 'ErgoComfort', 'unit_price': 249.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='71e75eba-b6bb-4ccf-b1f0-eaabe4726b80', node_type='4', metadata={'sku': 'ERG-CHR-002', 'standard_name': 'Standing Desk Converter XL', 'category': 'Furniture', 'manufacturer': 'ErgoComfort', 'unit_price': 249.99}, hash='0d7345e617ca30b5d0f914433f0f8dcc8ea4840d85e11d34d606384b14f2670e')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Standing Desk Converter XL ErgoComfort Extra-large standing desk converter with dual monitor support', mimetype='text/plain', start_char_idx=0, end_char_idx=100, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9263273563040769)]
# all matches >>  [NodeWithScore(node=TextNode(id_='613d5a9b-69d3-436b-92c3-1e9a4e3d3499', embedding=None, metadata={'sku': 'MON-ACC-002', 'standard_name': 'Dual Monitor Arm Professional', 'category': 'Monitor Accessories', 'manufacturer': 'TechPro', 'unit_price': 129.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='9be30a0d-95d6-4f61-baa8-18087851259c', node_type='4', metadata={'sku': 'MON-ACC-002', 'standard_name': 'Dual Monitor Arm Professional', 'category': 'Monitor Accessories', 'manufacturer': 'TechPro', 'unit_price': 129.99}, hash='dbe285c8cd7bbe67813eb35946600968cdd873e3129b4ce4e37cf1ec64abdc16')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Dual Monitor Arm Professional TechPro Professional-grade dual monitor arm with cable management', mimetype='text/plain', start_char_idx=0, end_char_idx=95, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9197825144705378)]
# all matches >>  [NodeWithScore(node=TextNode(id_='34a3ef50-db16-4c9a-9c78-3ee609f91835', embedding=None, metadata={'sku': 'ACM-WX-004', 'standard_name': 'Widget X Enterprise Bundle', 'category': 'Solutions', 'manufacturer': 'Acme Corporation', 'unit_price': 399.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='ec2e8469-a2d9-4aec-836a-1e677b57fac0', node_type='4', metadata={'sku': 'ACM-WX-004', 'standard_name': 'Widget X Enterprise Bundle', 'category': 'Solutions', 'manufacturer': 'Acme Corporation', 'unit_price': 399.99}, hash='32db679aa475233b1a66ee6622869876f5c65f2db1f70955ca11b7da825281e9')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Widget X Enterprise Bundle Acme Corporation Complete enterprise solution including Widget X and accessories', mimetype='text/plain', start_char_idx=0, end_char_idx=107, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.8845339059541446)]
# all matches >>  [NodeWithScore(node=TextNode(id_='642c9a7e-8442-46ce-b113-48f31bce69b3', embedding=None, metadata={'sku': 'IND-FST-203', 'standard_name': 'Industrial Fastener Kit Mixed', 'category': 'Fasteners', 'manufacturer': 'Industrial Supply Co', 'unit_price': 45.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='0adf8d91-4018-4264-9b0e-298dc79040da', node_type='4', metadata={'sku': 'IND-FST-203', 'standard_name': 'Industrial Fastener Kit Mixed', 'category': 'Fasteners', 'manufacturer': 'Industrial Supply Co', 'unit_price': 45.99}, hash='9e76a34003522d136c57bacb4831830695afc74321821c72dcec234c67817050')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Industrial Fastener Kit Mixed Industrial Supply Co Comprehensive kit of industrial fasteners in various sizes', mimetype='text/plain', start_char_idx=0, end_char_idx=109, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9222722697183935)]
# all matches >>  [NodeWithScore(node=TextNode(id_='ef19a18b-4bf2-40fa-a442-aeeccc632164', embedding=None, metadata={'sku': 'CAB-MGT-002', 'standard_name': 'Professional Cable Ties', 'category': 'Cable Management', 'manufacturer': 'OfficePro', 'unit_price': 9.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='eb786637-25df-4bc1-b6ba-541b4db31ee0', node_type='4', metadata={'sku': 'CAB-MGT-002', 'standard_name': 'Professional Cable Ties', 'category': 'Cable Management', 'manufacturer': 'OfficePro', 'unit_price': 9.99}, hash='a76d0f30d3f7c9606b352ac185671907e32853b9a3c58656f42539f1115de1bf')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Professional Cable Ties OfficePro Heavy-duty professional cable ties pack of 100', mimetype='text/plain', start_char_idx=0, end_char_idx=80, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9075453427148997)]
# all matches >>  [NodeWithScore(node=TextNode(id_='3a27ed98-7db0-47c9-864c-c97e8e6c8630', embedding=None, metadata={'sku': 'ACM-WX-005', 'standard_name': 'Widget X Service Bundle', 'category': 'Services', 'manufacturer': 'Acme Corporation', 'unit_price': 149.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='0eabfda1-416c-43cc-a6be-07040b699824', node_type='4', metadata={'sku': 'ACM-WX-005', 'standard_name': 'Widget X Service Bundle', 'category': 'Services', 'manufacturer': 'Acme Corporation', 'unit_price': 149.99}, hash='32a25738ff9be0ebfd52fe1881e55e79ad1710da31d7c111b5f7fb633a85c44e')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Widget X Service Bundle Acme Corporation Comprehensive service package for Widget X products', mimetype='text/plain', start_char_idx=0, end_char_idx=92, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.8435487735696562)]
# all matches >>  [NodeWithScore(node=TextNode(id_='1996e154-8214-4e4f-9118-10f705a9715d', embedding=None, metadata={'sku': 'ERG-ACC-003', 'standard_name': 'Premium Office Chair Mat', 'category': 'Accessories', 'manufacturer': 'ErgoComfort', 'unit_price': 59.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='9dc10020-adaa-4a1a-bc4e-e663136ec8a1', node_type='4', metadata={'sku': 'ERG-ACC-003', 'standard_name': 'Premium Office Chair Mat', 'category': 'Accessories', 'manufacturer': 'ErgoComfort', 'unit_price': 59.99}, hash='9cdbab1a78e5ecfa3d02c7ff60ef0df3ad8d591d7fbf8b1f46c2c618b7039f24')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Premium Office Chair Mat ErgoComfort Heavy-duty chair mat for carpet protection', mimetype='text/plain', start_char_idx=0, end_char_idx=79, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9075361794780364)]
# all matches >>  [NodeWithScore(node=TextNode(id_='61ec178f-3f93-4564-8e2b-27dcc016ded7', embedding=None, metadata={'sku': 'PWR-ACC-001', 'standard_name': 'Desktop Power Hub Pro', 'category': 'Power Accessories', 'manufacturer': 'TechPro', 'unit_price': 49.99}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='ba6e1053-d75f-49ee-ad1e-3f3fdf47a077', node_type='4', metadata={'sku': 'PWR-ACC-001', 'standard_name': 'Desktop Power Hub Pro', 'category': 'Power Accessories', 'manufacturer': 'TechPro', 'unit_price': 49.99}, hash='cabab655d4e25a7ac32097a428be88ecf2ea1ce6a6959461b5858be729a026c3')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Desktop Power Hub Pro TechPro Professional desktop power hub with surge protection', mimetype='text/plain', start_char_idx=0, end_char_idx=82, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.9150242678465662)]
# Step match_skus produced event EnrichedEvent
# Running step save_output
# Step save_output produced event StopEvent
# >> Matching SKUs
# >> Saving enriched data
# >> Saved output to data_out/workflow_output/enriched_invoice.csv

# %% [markdown]
# ### Check Enriched Invoice

# %%
df = pd.read_csv("data_out/workflow_output/enriched_invoice.csv")
df.head()
# Out:
#      invoice_id                         line_item  quantity  unit_price  \
# 0  INV-2024-001       Acme Widget Model X Premium        10       45.99
# 1  INV-2024-001  Blue Industrial Fasteners 2-inch        25        0.99
# 2  INV-2024-001    Widget X Replacement Parts Kit         2       15.50
# 3  INV-2024-002             ACME Premium Widget X        15       45.99
# 4  INV-2024-002    Industrial Blue Bolt Pack (2")        30        0.99
#
#          date  matched_sku               standard_name     category  \
# 0  2024-01-15   ACM-WX-002       Acme Widget X Premium      Widgets
# 1  2024-01-15  IND-FST-201  Industrial Fastener 2-inch    Fasteners
# 2  2024-01-15   ACM-WX-003    Widget X Maintenance Kit  Spare Parts
# 3  2024-01-16   ACM-WX-002       Acme Widget X Premium      Widgets
# 4  2024-01-16  IND-FST-201  Industrial Fastener 2-inch    Fasteners
#
#            manufacturer  match_confidence
# 0      Acme Corporation          0.918583
# 1  Industrial Supply Co          0.910306
# 2      Acme Corporation          0.879268
# 3      Acme Corporation          0.914013
# 4  Industrial Supply Co          0.838258
